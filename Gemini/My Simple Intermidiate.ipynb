# %%
# !pip install google-generativeai
# Out:
# Collecting google-generativeai
#   Using cached google_generativeai-0.8.6-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in c:\anaconda3\envs\aiml\lib\site-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in c:\anaconda3\envs\aiml\lib\site-packages (from google-generativeai) (2.30.3)
# Requirement already satisfied: google-api-python-client in c:\anaconda3\envs\aiml\lib\site-packages (from google-generativeai) (2.194.0)
# Requirement already satisfied: google-auth>=2.15.0 in c:\anaconda3\envs\aiml\lib\site-packages (from google-generativeai) (2.49.2)
# Requirement already satisfied: protobuf in c:\anaconda3\envs\aiml\lib\site-packages (from google-generativeai) (5.29.6)
# Requirement already satisfied: pydantic in c:\anaconda3\envs\aiml\lib\site-packages (from google-generativeai) (2.12.5)
# Requirement already satisfied: tqdm in c:\anaconda3\envs\aiml\lib\site-packages (from google-generativeai) (4.67.3)
# Requirement already satisfied: typing-extensions in c:\anaconda3\envs\aiml\lib\site-packages (from google-generativeai) (4.15.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\anaconda3\envs\aiml\lib\site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.27.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in c:\anaconda3\envs\aiml\lib\site-packages (from google-api-core->google-generativeai) (1.74.0)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in c:\anaconda3\envs\aiml\lib\site-packages (from google-api-core->google-generativeai) (2.32.5)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\anaconda3\envs\aiml\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\anaconda3\envs\aiml\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\anaconda3\envs\aiml\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\anaconda3\envs\aiml\lib\site-packages (from google-auth>=2.15.0->google-generativeai) (46.0.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\anaconda3\envs\aiml\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\envs\aiml\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\anaconda3\envs\aiml\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\envs\aiml\lib\site-packages (from requests<3.0.0,>=2.20.0->google-api-core->google-generativeai) (2025.10.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\anaconda3\envs\aiml\lib\site-packages (from cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.0.0)
# Requirement already satisfied: pycparser in c:\anaconda3\envs\aiml\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth>=2.15.0->google-generativeai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\anaconda3\envs\aiml\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\anaconda3\envs\aiml\lib\site-packages (from google-api-python-client->google-generativeai) (0.31.2)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\anaconda3\envs\aiml\lib\site-packages (from google-api-python-client->google-generativeai) (0.3.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\anaconda3\envs\aiml\lib\site-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: pyparsing<4,>=3.1 in c:\anaconda3\envs\aiml\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.5)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\anaconda3\envs\aiml\lib\site-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\anaconda3\envs\aiml\lib\site-packages (from pydantic->google-generativeai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\anaconda3\envs\aiml\lib\site-packages (from pydantic->google-generativeai) (0.4.2)
# Requirement already satisfied: colorama in c:\anaconda3\envs\aiml\lib\site-packages (from tqdm->google-generativeai) (0.4.6)
# Using cached google_generativeai-0.8.6-py3-none-any.whl (155 kB)
# Installing collected packages: google-generativeai
# Successfully installed google-generativeai-0.8.6

# %%
from google import genai

client = genai.Client(api_key="AIzaSyBfpvtaQdMWCQ7CY--3xEqJT7XOCAyZIog")

print(" Gemini Chatbot Ready (type 'bye' to exit)")

while True:
    user_input = input("You: ")

    if user_input.lower() == "bye":
        print("Bot: Bye ")
        break

    try:
        response = client.models.generate_content(
            model="models/gemini-2.5-flash",
            contents=user_input
        )

        print("Bot:", response.text)

    except Exception as e:
        print("⚠️ Error:", e)
# Out:
# 🤖 Gemini Chatbot Ready (type 'bye' to exit)
# You:  hi
# Bot: Hi there! How can I help you today?
# You:  today i want fish fry
# ⚠️ Error: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
# You:  cooking ideas for fish fry
# Bot: A fish fry is a classic comfort food, and there are endless ways to customize it! Here are some cooking ideas to elevate your fish fry experience:
#
# ## I. Choose Your Fish Wisely
#
# *   **Firm White Fish:** Cod, Haddock, Tilapia, Catfish, Snapper, Flounder, Perch, Whiting, Pollock, Basa. These hold up well to frying and have a mild flavor.
# *   **Freshness:** Always opt for fresh, high-quality fish.
#
# ## II. Coating/Crust Variations
#
# This is where the magic happens!
#
# 1.  **Classic Cornmeal Crust (Southern Style):**
#     *   **Ingredients:** Yellow cornmeal, all-purpose flour, paprika, cayenne pepper (optional), garlic powder, onion powder, salt, black pepper.
#     *   **Method:** Dredge fish in seasoned flour, then egg wash, then seasoned cornmeal. Fry until golden and crispy. Gives a fantastic texture and flavor.
#
# 2.  **Crispy Beer Batter:**
#     *   **Ingredients:** All-purpose flour, beer (lager or pale ale works great), baking powder, salt, pepper, a touch of paprika.
#     *   **Method:** Mix ingredients until just combined (don't overmix). Dip fish fillets into the batter and fry immediately. Creates a light, airy, incredibly crispy shell.
#
# 3.  **Panko Breadcrumb Crust (Extra Crunchy):**
#     *   **Ingredients:** Panko breadcrumbs, flour, egg, your choice of seasonings (e.g., lemon pepper, dried herbs).
#     *   **Method:** Dredge fish in seasoned flour, then egg wash, then seasoned Panko. Panko provides an exceptionally crunchy, almost shaggy crust.
#
# 4.  **Gluten-Free Options:**
#     *   Use a mix of rice flour and cornstarch, or specific gluten-free all-purpose flour blends for your dredge or batter. Chickpea flour can also add a unique flavor.
#
# 5.  **Seasoned Flour Dredge (Simple & Light):**
#     *   **Ingredients:** All-purpose flour generously seasoned with salt, pepper, garlic powder, onion powder, Old Bay, paprika, cayenne, dried herbs (dill, parsley, thyme).
#     *   **Method:** Simply dredge the fish in the seasoned flour and fry. Provides a lighter, less thick crust.
#
# ## III. Flavor Profiles for Seasoning (in your coating)
#
# Beyond salt and pepper, consider these additions:
#
# *   **Classic Southern:** Paprika, cayenne, garlic powder, onion powder, dried oregano, thyme.
# *   **Lemon-Herb:** Lemon zest, dried dill, parsley, a hint of garlic.
# *   **Spicy Cajun/Creole:** More cayenne, smoked paprika, white pepper, black pepper, onion powder, oregano, thyme.
# *   **Mediterranean:** Dried oregano, marjoram, a pinch of sumac, garlic powder.
# *   **Asian-Inspired:** A touch of five-spice powder, ginger powder, white pepper.
# *   **Old Bay Seasoning:** A classic for seafood.
#
# ## IV. Cooking Methods (Beyond Deep Frying)
#
# *   **Pan-Frying:** Use a heavy-bottomed skillet with about 1/2 inch of oil. Flip once. Less oil, still great crust.
# *   **Air Fryer "Frying":** For a healthier option! Coat fish as desired (a seasoned flour or light breadcrumb works best). Spray generously with oil (or brush with oil). Air fry at 375-400°F (190-200°C) for 10-15 minutes, flipping halfway, until golden and cooked through.
# *   **Oven "Frying" (Baked Fish):** Coat fish with seasoned Panko or cornmeal. Place on a wire rack over a baking sheet. Spray lightly with oil. Bake at 400-425°F (200-220°C) for 15-20 minutes, flipping halfway, until crispy and cooked.
#
# ## V. Sauces & Dips
#
# Crucial for a fish fry!
#
# *   **Classic Tartar Sauce:** Mayonnaise, finely diced pickles/relish, capers, lemon juice, fresh dill or parsley.
# *   **Spicy Remoulade:** A kicked-up tartar with Creole mustard, horseradish, hot sauce, and sometimes finely chopped celery/bell pepper.
# *   **Chipotle Aioli:** Mayonnaise, adobo sauce from chipotles, lime juice, garlic powder.
# *   **Sriracha Mayo:** Simple mix of Sriracha and mayo.
# *   **Lemon-Dill Yogurt Sauce:** Greek yogurt, lemon juice, fresh dill, salt, pepper. A lighter option.
# *   **Sweet Chili Sauce:** Great for an Asian twist.
# *   **Malt Vinegar:** A must for British-style fish and chips.
# *   **Simple Lemon Wedges:** Always a necessity to brighten the flavor.
#
# ## VI. Side Dishes
#
# *   **French Fries:** Classic! Hand-cut, shoestring, or sweet potato fries.
# *   **Coleslaw:** Creamy mayo-based or tangy vinegar-based.
# *   **Hushpuppies:** Southern fried cornmeal fritters, often with onion.
# *   **Corn on the Cob:** Grilled or boiled.
# *   **Macaroni and Cheese:** Ultimate comfort food pairing.
# *   **Roasted or Steamed Vegetables:** Asparagus, green beans, broccoli for a fresher balance.
# *   **Green Salad:** A light, fresh counterpoint.
# *   **Onion Rings:** Another fried favorite.
# *   **Dirty Rice or Jambalaya:** If going for a Cajun-spiced fish.
#
# ## VII. Serving Suggestions
#
# *   **Traditional Platter:** Pile high with fish, fries, and slaw.
# *   **Fish Tacos:** Flaky fried fish works perfectly in a taco with cabbage slaw, a creamy sauce, and pico de gallo.
# *   **Fish Sandwich/Po'Boy:** Serve on a hoagie roll or brioche bun with lettuce, tomato, pickles, and plenty of tartar/remoulade.
# *   **Fish & Chips Style:** Wrap in newspaper (or food-safe paper printed with newspaper design) with malt vinegar.
#
# **Pro Tip:** Maintain the oil temperature! Too low, and the fish will be greasy. Too high, and the coating will burn before the fish cooks through. Aim for 350-375°F (175-190°C).
#
# Have fun experimenting and enjoy your delicious fish fry!
