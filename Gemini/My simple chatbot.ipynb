# %%
from google import genai

client = genai.Client(api_key="AIzaSyBfpvtaQdMWCQ7CY--3xEqJT7XOCAyZIog")

models = client.models.list()

for m in models:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/aqa
# models/imagen-4.0-generate-001
# models/imagen-4.0-ultra-generate-001
# models/imagen-4.0-fast-generate-001
# models/veo-2.0-generate-001
# models/veo-3.0-generate-001
# models/veo-3.0-fast-generate-001
# models/veo-3.1-generate-preview
# models/veo-3.1-fast-generate-preview
# models/veo-3.1-lite-generate-preview
# models/gemini-2.5-flash-native-audio-latest
# models/gemini-2.5-flash-native-audio-preview-09-2025
# models/gemini-2.5-flash-native-audio-preview-12-2025
# models/gemini-3.1-flash-live-preview

# %%
from google import genai

client = genai.Client(api_key="AIzaSyBfpvtaQdMWCQ7CY--3xEqJT7XOCAyZIog")

print("Gemini Chatbot Ready (type 'bye' to exit)")

while True:
    user = input("You: ")

    if user.lower() == "bye":
        print("Bot: Goodbye ")
        break

    try:
        response = client.models.generate_content(
            model="models/gemini-2.5-flash",
            contents=user
        )
        print("Bot:", response.text)

    except Exception as e:
        print("⚠️ Error:", e)
# Out:
# 🤖 Gemini Chatbot Ready (type 'bye' to exit)
# You:  gIVE ME 3 IDEAS FOR COOKING
# Bot: Here are 3 versatile and delicious cooking ideas to get you started:
#
# 1.  **Sheet Pan Dinner Extravaganza:**
#     *   **The Idea:** Toss everything (protein + veggies + seasoning) onto one sheet pan, bake, and you're done! Minimal cleanup, maximum flavor.
#     *   **How it works:**
#         *   **Choose your protein:** Chicken thighs/breast (cut into chunks), sausage (sliced), firm tofu (cubed), fish fillets (salmon, cod).
#         *   **Choose your veggies:** Broccoli florets, bell peppers (sliced), red onion (wedges), potatoes/sweet potatoes (cubed), Brussels sprouts (halved), carrots (sliced).
#         *   **Season generously:** Olive oil, salt, pepper, garlic powder, onion powder, paprika, dried herbs (rosemary, thyme, oregano). A squeeze of lemon juice after baking is great too!
#         *   **Bake:** Arrange in a single layer (don't overcrowd!) on a baking sheet at 400°F (200°C) until everything is tender and lightly caramelized. Cooking times will vary depending on your ingredients (e.g., chicken and potatoes might take 25-35 min, fish and asparagus much less).
#     *   **Why it's great:** Super easy cleanup, healthy, infinitely customizable, and great for meal prepping.
#
# 2.  **Customizable Pasta Bowl:**
#     *   **The Idea:** Start with your favorite pasta and build a quick, flavorful sauce around it with ingredients you have on hand.
#     *   **How it works:**
#         *   **Cook your pasta:** Choose any shape you like (spaghetti, penne, rotini, fettuccine). Cook according to package directions. **Crucial tip:** Reserve about a cup of the starchy pasta water before draining!
#         *   **Build the sauce:**
#             *   **Option A (Quick Tomato):** Sauté garlic and chili flakes in olive oil, add a can of crushed tomatoes or jarred marinara, simmer for 10-15 mins.
#             *   **Option B (Creamy Garlic):** Sauté garlic in butter, add a splash of white wine (optional), then heavy cream, parmesan cheese.
#             *   **Option C (Pesto Power):** Simply combine pesto with a little olive oil.
#             *   **Option D (Garlic & Oil):** Sauté lots of garlic in olive oil, add red pepper flakes.
#         *   **Add extras:** Sautéed vegetables (spinach, mushrooms, cherry tomatoes, zucchini), cooked protein (shredded chicken, shrimp, ground beef/sausage, chickpeas), or fresh herbs.
#         *   **Finish:** Add the cooked pasta to the sauce, toss well. Use some of that reserved pasta water to loosen the sauce and help it cling to the pasta. Finish with grated cheese (parmesan, pecorino).
#     *   **Why it's great:** Quick, comforting, endless flavor combinations, and a fantastic way to use up leftover ingredients.
#
# 3.  **Speedy Stir-Fry:**
#     *   **The Idea:** A vibrant, healthy, and lightning-fast meal made in one pan with fresh ingredients and a savory sauce.
#     *   **How it works:**
#         *   **Prep all ingredients first:** This is key for stir-fries!
#             *   **Protein:** Chicken breast/thighs, beef strips, shrimp, firm tofu (cubed). Cut into bite-sized pieces.
#             *   **Veggies:** Broccoli florets, bell peppers (sliced), carrots (julienned), snap peas, mushrooms, bok choy, baby corn, onions (sliced).
#             *   **Aromatics:** Minced garlic and ginger.
#             *   **Sauce:** Whisk together soy sauce (or tamari), a touch of sesame oil, rice vinegar, a teaspoon of sugar/honey, and a cornstarch slurry (1 tsp cornstarch mixed with 2 tbsp water) for thickening.
#         *   **Cook:** Heat a large skillet or wok over high heat with a little oil.
#             *   Sear protein in batches until cooked, remove from pan.
#             *   Add more oil if needed, stir-fry harder vegetables (carrots, broccoli) for a few minutes.
#             *   Add softer vegetables (bell peppers, mushrooms) and aromatics, stir-fry until tender-crisp.
#             *   Return protein to the pan.
#             *   Pour in the sauce, stirring constantly until it thickens and coats everything.
#         *   **Serve:** Immediately over steamed rice or noodles. Garnish with sesame seeds or chopped green onions.
#     *   **Why it's great:** Super fast, healthy, uses up whatever veggies you have, and packed with flavor.
#
# Happy cooking!
