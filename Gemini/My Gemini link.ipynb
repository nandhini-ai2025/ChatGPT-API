# %%
# !pip install gradio
# Out:
# ...
#    ---------------------------------------- 0.0/19.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/19.6 MB ? eta -:--:--
#    - -------------------------------------- 0.8/19.6 MB 2.8 MB/s eta 0:00:07
#    --- ------------------------------------ 1.6/19.6 MB 3.0 MB/s eta 0:00:07
#    ---- ----------------------------------- 2.1/19.6 MB 2.8 MB/s eta 0:00:07
#    ----- ---------------------------------- 2.6/19.6 MB 2.7 MB/s eta 0:00:07
#    ------ --------------------------------- 3.4/19.6 MB 2.9 MB/s eta 0:00:06
#    -------- ------------------------------- 3.9/19.6 MB 3.0 MB/s eta 0:00:06
#    --------- ------------------------------ 4.7/19.6 MB 3.1 MB/s eta 0:00:05
#    ----------- ---------------------------- 5.5/19.6 MB 3.2 MB/s eta 0:00:05
#    ------------ --------------------------- 6.3/19.6 MB 3.1 MB/s eta 0:00:05
#    -------------- ------------------------- 7.1/19.6 MB 3.2 MB/s eta 0:00:04
# ...

# %%
from google import genai
import gradio as gr

client = genai.Client(api_key="AIzaSyBfpvtaQdMWCQ7CY--3xEqJT7XOCAyZIog")

#System prompt
system_msg = "You are a financial expert specializing in real estate investment and negotiation."

#  Chat function
def CustomGemini(user_input):
    response = client.models.generate_content(
        model="models/gemini-2.5-flash",
        contents=system_msg + "\nUser: " + user_input
    )
    return response.text

# Gradio UI
demo = gr.Interface(
    fn=CustomGemini,
    inputs="text",
    outputs="text",
    title=" My Saving Assistant (Gemini AI)"
)

# Launch with global link
demo.launch(share=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# Could not create share link. Please check your internet connection or our status page: https://status.gradio.app.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
