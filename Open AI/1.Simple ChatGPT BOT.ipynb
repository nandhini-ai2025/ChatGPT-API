# %%
#!pip install openai
# !pip uninstall torch -y
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# WARNING: Skipping torch as it is not installed.
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Using cached https://download-r2.pytorch.org/whl/cpu/torch-2.11.0%2Bcpu-cp313-cp313-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: torchvision in c:\anaconda3\envs\aiml\lib\site-packages (0.26.0+cpu)
# Requirement already satisfied: torchaudio in c:\anaconda3\envs\aiml\lib\site-packages (2.11.0+cpu)
# Requirement already satisfied: filelock in c:\anaconda3\envs\aiml\lib\site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\anaconda3\envs\aiml\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in c:\anaconda3\envs\aiml\lib\site-packages (from torch) (78.1.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\anaconda3\envs\aiml\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\anaconda3\envs\aiml\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\anaconda3\envs\aiml\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\anaconda3\envs\aiml\lib\site-packages (from torch) (2026.3.0)
# Requirement already satisfied: numpy in c:\anaconda3\envs\aiml\lib\site-packages (from torchvision) (2.3.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\anaconda3\envs\aiml\lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda3\envs\aiml\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda3\envs\aiml\lib\site-packages (from jinja2->torch) (3.0.2)
# Using cached https://download-r2.pytorch.org/whl/cpu/torch-2.11.0%2Bcpu-cp313-cp313-win_amd64.whl (114.5 MB)
# Installing collected packages: torch
# Successfully installed torch-2.11.0+cpu

# %%
import torch
print("Torch installed:",torch.__version__)
# Out:
# Torch installed: 2.11.0+cpu

# %%
#Step 1: Install (run once)
# !pip install transformers

#Step 2: Import
from transformers import pipeline

#Step 3: Load free model
chatbot = pipeline("text-generation", model="gpt2")

print("Free Chatbot (type 'exit' to stop)\n")

#Step 4: Chat loop
while True: user_input = input("You: ")

if user_input.lower() == "exit":
    print("Bot: Goodbye 👋")
    break

response = chatbot(user_input, max_length=100, num_return_sequences=1)

print("Bot:", response[0]['generated_text'])
# Out:
# Requirement already satisfied: transformers in c:\anaconda3\envs\aiml\lib\site-packages (5.5.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in c:\anaconda3\envs\aiml\lib\site-packages (from transformers) (1.9.0)
# Requirement already satisfied: numpy>=1.17 in c:\anaconda3\envs\aiml\lib\site-packages (from transformers) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\envs\aiml\lib\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\anaconda3\envs\aiml\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex>=2025.10.22 in c:\anaconda3\envs\aiml\lib\site-packages (from transformers) (2026.2.28)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\anaconda3\envs\aiml\lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in c:\anaconda3\envs\aiml\lib\site-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\anaconda3\envs\aiml\lib\site-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in c:\anaconda3\envs\aiml\lib\site-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in c:\anaconda3\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\anaconda3\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in c:\anaconda3\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\anaconda3\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\anaconda3\envs\aiml\lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in c:\anaconda3\envs\aiml\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.10.0)
# Requirement already satisfied: certifi in c:\anaconda3\envs\aiml\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\anaconda3\envs\aiml\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in c:\anaconda3\envs\aiml\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\anaconda3\envs\aiml\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: colorama in c:\anaconda3\envs\aiml\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\anaconda3\envs\aiml\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in c:\anaconda3\envs\aiml\lib\site-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\anaconda3\envs\aiml\lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\anaconda3\envs\aiml\lib\site-packages (from typer->transformers) (14.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\anaconda3\envs\aiml\lib\site-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\anaconda3\envs\aiml\lib\site-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\anaconda3\envs\aiml\lib\site-packages (from rich>=12.3.0->typer->transformers) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\anaconda3\envs\aiml\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# C:\Anaconda3\envs\aiml\Lib\site-packages\huggingface_hub\file_download.py:138: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Vino Nandu\.cache\huggingface\hub\models--gpt2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Free Chatbot (type 'exit' to stop)
# You:  hello
# You:  AI
